# %%
import pandas as pd
import os
import lmr_analyzer as lmr

# %%
os.chdir('../..')
df = pd.read_csv('data/last_mile_routes/historical_data_guarulhos.csv')

# %%
df
# Out:
#              Date    RouteID  Placa  Cod. Cliente  Actual Order  \
# 0      03/01/2015  route0004  vhl04  customer0552           3.0
# 1      03/01/2015  route0004  vhl04  customer0559           4.0
# 2      03/01/2015  route0004  vhl04  customer0562          10.0
# 3      03/01/2015  route0004  vhl04  customer0551           9.0
# 4      03/01/2015  route0004  vhl04  customer0553           7.0
# ...           ...        ...    ...           ...           ...
# 58560  30/05/2015  route4620  vhl14  customer3747          28.0
# 58561  30/05/2015  route4620  vhl14  customer3911          27.0
# 58562  30/05/2015  route4620  vhl14  customer0163          30.0
# 58563  30/05/2015  route4620  vhl14  customer1026          31.0
# 58564  30/05/2015  route4620  vhl14  customer0155          29.0
#
#        Planned Order Departure from DC (hh:mm:ss) Arrival time (hh:mm:ss)  \
# 0                  1                     08:40:00                10:54:51
# ...

# %%
list(df.keys())
# Out:
# ['Date',
#  'RouteID',
#  'Placa',
#  'Cod. Cliente',
#  'Actual Order',
#  'Planned Order',
#  'Departure from DC (hh:mm:ss)',
#  'Arrival time (hh:mm:ss)',
#  'Return entry into DC (hh:mm:ss)',
#  'Loaded Boxes',
#  'Rejected Boxes',
#  'Delivery Attempt',
#  'Latitude (deg)',
#  'Longitude (deg)',
#  'Neighborhood',
#  'City']

# %%
# Sort the dataframe by the 'RouteID' key
df = df.sort_values(by=['RouteID'])

# %%
# Iterate over the dataframe and print the first 5 rows
for index, row in df.iterrows():
    routeID = row['RouteID']
    package = lmr.package()
    stop = lmr.stop()
    
    # print(row['Date'])

route = lmr.route()
# Out:
# 03/01/2015
# 03/01/2015
# 03/01/2015
# 03/01/2015
# 03/01/2015

# %%
guarulhos = lmr.analysis()
